# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-10, 10, 10000)
y = x**2 + 2*x +2
fig, ax = plt.subplots()
a = ax.plot(x,y)

# %%
from sympy import *
x, y = symbols('x y')
exp = x**2 + 2*x*2 + 2
print(diff(exp))
exp.subs(x, x)
exp.subs(x, y)
# Out:
# 2*x + 4
# y**2 + 4*y + 2

# %%
def squared(x):
    return x**3
expr = x**2 + y**2
f = lambdify((x, y), expr, {" ** ":diff})
f(20,3)
# Out:
# 409
